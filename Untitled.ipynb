# %% [markdown]
# #### News getting 2.0

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='22901f790d59422e817ef038a62c6c38')

# %%
my_news2 = newsapi.get_everything(q='S&P 500 Index',
                                sources = 'the-wall-street-journal,bloomberg,reuters,google-news,business-insider,cnbc,financial-post,time,the-washington-post,seeking-alpha',
                                 language = 'en')

# %%
sources = newsapi.get_sources()

# %%
import pandas as pd
news_df = pd.DataFrame(my_news['articles'])
news_df.head()
# Out:
#                                             author  \
# 0                                Reuters Editorial
# 1                                     Swati Pandey
# 2                                   Larysa Harapyn
# 3  R. Paul Herman, CEO and founder of HIP Investor
# 4                                     Swati Pandey
#
#                                              content  \
# 0  LONDON (Reuters) - The U.S. benchmark S&amp;P ...
# 1  SYDNEY (Reuters) - Asian shares started on a f...
# 2  Comments\r\nPostmedia is pleased to bring you ...
# 3  President Donald Trump loves climate-wrecking ...
# 4  SYDNEY (Reuters) - Asian shares neared nine-mo...
#
#                                          description           publishedAt  \
# 0  The U.S. benchmark S&P 500 stock index will sc...  2019-04-05T09:38:40Z
# 1  Asian shares started on a firm footing on Mond...  2019-04-15T00:53:55Z
# 2  BMO chief investment strategist explains his y...  2019-04-15T15:08:01Z
# ...

# %%
import seaborn as sns
info_series = pd.DataFrame(news_df['source'])
info_df = info_series['source'].apply(pd.Series)
sns.barplot(info_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-599ff16a1cb5> in <module>
#       2 info_series = pd.DataFrame(news_df['source'])
#       3 info_df = info_series['source'].apply(pd.Series)
# ----> 4 sns.barplot(info_df)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ...

# %%
best_news_df = pd.DataFrame(my_news2['articles'])
best_news_df.head()
# Out:
#               author                                            content  \
# 0   Associated Press  (NEW YORK) — The S&amp;P 500 index is closing ...
# 1        Arjun Reddy  Warren Buffett shot down expectations that the...
# 2         Marley Jay  Big stock indexes are setting records again, b...
# 3  Reuters Editorial  NEW YORK (Reuters) - The S&amp;P 500 and the N...
# 4     Theron Mohamed  Prediction:\r\n "Over a ten-year period commen...
#
#                                          description           publishedAt  \
# 0  The S&P 500 index and the Nasdaq index closed ...  2019-04-23T21:10:11Z
# 1  The legendary investor Warre n Buffett predict...  2019-04-26T10:02:00Z
# 2  The S&P 500 and Nasdaq both set record highs t...  2019-04-29T09:58:00Z
# 3  The S&P 500 and the Nasdaq edged up to their h...  2019-04-29T15:19:25Z
# 4  Legendary investor Warren Buffett avoids makin...  2019-04-19T12:46:00Z
#
#                                               source  \
# ...

# %%
best_news_df['description'][0]
# Out:
# 'The S&P 500 index and the Nasdaq index closed at record highs recouping all the ground it lost in a nosedive in late 2018.'

# %%
news_df2 = pd.DataFrame(my_news2['articles'])
my_news2
# Out:
# {'status': 'ok',
#  'totalResults': 480,
#  'articles': [{'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Associated Press',
#    'title': 'S&P 500 and Nasdaq Closed at Record Highs, Recouping Last Year’s Major Losses',
#    'description': 'The S&P 500 index and the Nasdaq index closed at record highs recouping all the ground it lost in a nosedive in late 2018.',
#    'url': 'http://time.com/5576552/sp-500-nasdaq-record-highs/',
#    'urlToImage': 'https://timedotcom.files.wordpress.com/2019/04/sp-500-nasdaq-record-highs.jpg?quality=85',
#    'publishedAt': '2019-04-23T21:10:11Z',
#    'content': '(NEW YORK) — The S&amp;P 500 index is closing at a record high, surpassing the peak it set last September and recouping all the ground it lost in a nosedive late last year.\r\nThe Nasdaq index also closed at a record high Tuesday.\r\nThe market has risen sharply … [+519 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Arjun Reddy',
# ...

# %%
def sentiment_spacy(searies):
    list_of_sentiment = []
    for sent in searies:
        #pattern = re.sub('…','',sent)
        #sentence = pattern2.sub('',sent)
        doc = nlp(sent)
        list_of_sentiment.append(doc._.polarity_scores)
    return pd.DataFrame(list_of_sentiment)

# %%
import spacy
from spacy.tokens import Doc
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sentiment_analyzer = SentimentIntensityAnalyzer()
def polarity_scores(doc):
    return sentiment_analyzer.polarity_scores(doc.text)
 
Doc.set_extension('polarity_scores', getter=polarity_scores, force = True)
 
nlp = spacy.load('en')
doc = nlp("Really Whaaat event apple nice! it!")
print(doc._.polarity_scores)
# Out:
# {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'compound': 0.5242}

# %%
print(best_news_df['description'][0])
# Out:
# The S&P 500 index and the Nasdaq index closed at record highs recouping all the ground it lost in a nosedive in late 2018.

# %%
print(best_news_df['content'][1])
# Out:
# Warren Buffett shot down expectations that the conglomerate Berkshire Hathaway will significantly outperform the S&amp;P 500 going forward.
#  The billionaire investor, dubbed the "Oracle of Omaha," told The Financial Times that Berkshire Hathaway, the compan… [+2522 chars]

# %%
import re

# %%
best_news_df['cleanned_content'] = [re.sub('amp;','',i) for i in best_news_df['content']]
best_news_df['cleanned_content'] = [re.sub('\r\n','',i) for i in best_news_df['cleanned_content']]

# %%
best_news_df['cleanned_content'][0]
# Out:
# '(NEW YORK) — The S&P 500 index is closing at a record high, surpassing the peak it set last September and recouping all the ground it lost in a nosedive late last year.The Nasdaq index also closed at a record high Tuesday.The market has risen sharply … [+519 chars]'

# %%
spacy_desc = sentiment_spacy(best_news_df['description'])
spacy_title = sentiment_spacy(best_news_df['title'])
spacy_content = sentiment_spacy(best_news_df['cleanned_content'])

# %%
spacy_content.head(10)
# Out:
#    compound    neg    neu    pos
# 0   -0.3182  0.051  0.949  0.000
# 1    0.0000  0.000  1.000  0.000
# 2    0.5499  0.000  0.924  0.076
# 3    0.8338  0.000  0.826  0.174
# 4    0.0000  0.000  1.000  0.000
# 5    0.0000  0.000  1.000  0.000
# 6    0.4215  0.102  0.727  0.171
# 7    0.5574  0.000  0.897  0.103
# 8    0.8074  0.000  0.799  0.201
# 9    0.4310  0.034  0.852  0.114

# %%
spacy_desc.head(10)
# Out:
#    compound    neg    neu    pos
# 0   -0.3182  0.095  0.905  0.000
# 1    0.0000  0.000  1.000  0.000
# 2   -0.1695  0.034  0.966  0.000
# 3    0.8338  0.000  0.807  0.193
# 4    0.0258  0.138  0.742  0.120
# 5    0.3400  0.000  0.946  0.054
# 6    0.6705  0.000  0.879  0.121
# 7    0.0000  0.000  1.000  0.000
# 8    0.7269  0.000  0.792  0.208
# 9    0.3716  0.086  0.754  0.160

# %%
best_news_df['description'][0]
# Out:
# 'The S&P 500 index and the Nasdaq index closed at record highs recouping all the ground it lost in a nosedive in late 2018.'

# %%
#By grams

# %%
spacy_title.head(10)
# Out:
#    compound    neg    neu    pos
# 0   -0.4019  0.184  0.816  0.000
# 1   -0.2411  0.151  0.849  0.000
# 2   -0.2263  0.101  0.899  0.000
# 3   -0.2960  0.196  0.804  0.000
# 4   -0.5994  0.196  0.804  0.000
# 5    0.0000  0.000  1.000  0.000
# 6    0.0000  0.000  1.000  0.000
# 7    0.0000  0.000  1.000  0.000
# 8    0.2960  0.000  0.804  0.196
# 9   -0.2263  0.303  0.516  0.181

# %%
best_news_df['title'][5]
# Out:
# "The stock market just hit a record high and history suggests it's headed even higher"

# %%
# Out:
# 20

# %%
spacy_title.describe()
# Out:
#         compound        neg        neu        pos
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.004595   0.081100   0.822500   0.096400
# std     0.411843   0.108923   0.167624   0.164072
# min    -0.665900   0.000000   0.516000   0.000000
# 25%    -0.254825   0.000000   0.737500   0.000000
# 50%     0.000000   0.000000   0.810000   0.000000
# 75%     0.074000   0.187000   1.000000   0.184750
# max     0.771700   0.303000   1.000000   0.462000

# %%
print(type(spacy_sent))
print(type(best_news_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
spacy_sent.head()
# Out:
#    compound    neg    neu    pos
# 0   -0.3182  0.095  0.905  0.000
# 1    0.0000  0.000  1.000  0.000
# 2   -0.1695  0.034  0.966  0.000
# 3    0.8338  0.000  0.807  0.193
# 4    0.0258  0.138  0.742  0.120

# %%
best_news_df['title'][0]
# Out:
# 'S&P 500 and Nasdaq Closed at Record Highs, Recouping Last Year’s Major Losses'

# %%
sources
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'abc-news',
#    'name': 'ABC News',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'url': 'https://abcnews.go.com',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'abc-news-au',
#    'name': 'ABC News (AU)',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'url': 'http://www.abc.net.au/news',
#    'category': 'general',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'aftenposten',
#    'name': 'Aftenposten',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'url': 'https://www.aftenposten.no',
#    'category': 'general',
#    'language': 'no',
#    'country': 'no'},
# ...
